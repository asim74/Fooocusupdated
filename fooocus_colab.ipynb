# %%
# !pip install pygit2 'numpy<2.0.0'
# !pip uninstall -y cupy-cuda12x cupy
# %cd /content
![ ! -d 'Fooocus' ] && git clone https://github.com/asim74/Fooocusupdated.git Fooocus
# %cd /content/Fooocus
# !git pull
# !python entry_with_update.py --share --always-high-vram
